# %% [markdown]
# #Install and Import

# %%
# !pip install matplotlib import basemap
# !pip install basemap matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# ERROR: Could not find a version that satisfies the requirement import (from versions: none)
# ERROR: No matching distribution found for import
# Requirement already satisfied: basemap in /usr/local/lib/python3.10/dist-packages (1.3.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: basemap-data<1.4,>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from basemap) (1.3.2)
# Requirement already satisfied: pyshp<2.4,>=1.2 in /usr/local/lib/python3.10/dist-packages (from basemap) (2.3.1)
# Requirement already satisfied: pyproj<3.7.0,>=1.9.3 in /usr/local/lib/python3.10/dist-packages (from basemap) (3.6.0)
# Requirement already satisfied: numpy<1.26,>=1.21 in /usr/local/lib/python3.10/dist-packages (from basemap) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj<3.7.0,>=1.9.3->basemap) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pip install learn2map
# Out:
# Requirement already satisfied: learn2map in /usr/local/lib/python3.10/dist-packages (0.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from learn2map) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from learn2map) (1.5.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from learn2map) (4.9.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->learn2map) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->learn2map) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->learn2map) (1.16.0)

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
nom.geocode('chitwan')
# Out:
# Location(Chitwan, Narayani, (27.584939239, 84.434573513, 0.0))

# %% [markdown]
# #Check geo location

# %%
s = nom.geocode('kathmandu')

# %%
s.latitude
# Out:
# 27.69329

# %%
s.longitude
# Out:
# 85.32227

# %% [markdown]
# #Install folium and import

# %%
 pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2023.7.22)

# %%
import folium

# %%
map =folium.Map(location= [27.58493923900005,84.43457351300003],zoom_start = 10)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8541a768897f0dc86308b3a5a8257178 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8541a768897f0dc86308b3a5a8257178&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8541a768897f0dc86308b3a5a8257178 = L.map(
#                 &quot;map_8541a768897f0dc86308b3a5a8257178&quot;,
#                 {
#                     center: [27.58493923900005, 84.43457351300003],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86ff8c040aa203b180180d79b217f38c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8541a768897f0dc86308b3a5a8257178);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#add child method
map.add_child(folium.Marker(location=[27.58493923900005,84.43457351300003],popup='chitwan',icon = folium.Icon(color='blue')))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8541a768897f0dc86308b3a5a8257178 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8541a768897f0dc86308b3a5a8257178&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8541a768897f0dc86308b3a5a8257178 = L.map(
#                 &quot;map_8541a768897f0dc86308b3a5a8257178&quot;,
#                 {
#                     center: [27.58493923900005, 84.43457351300003],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86ff8c040aa203b180180d79b217f38c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8541a768897f0dc86308b3a5a8257178);
#
#
#             var marker_0a788caa92c9951f75969114e19d19a1 = L.marker(
#                 [27.58493923900005, 84.43457351300003],
#                 {}
#             ).addTo(map_8541a768897f0dc86308b3a5a8257178);
#
#
#             var icon_93aebc0ace772bf9a4310e237d3ba09f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0a788caa92c9951f75969114e19d19a1.setIcon(icon_93aebc0ace772bf9a4310e237d3ba09f);
#
#
#         var popup_4c19baa105f5382f8a12f35965f41ffd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eae00700af11ebb461cf5d9b8efdee38 = $(`&lt;div id=&quot;html_eae00700af11ebb461cf5d9b8efdee38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;chitwan&lt;/div&gt;`)[0];
#                 popup_4c19baa105f5382f8a12f35965f41ffd.setContent(html_eae00700af11ebb461cf5d9b8efdee38);
#
#
#
#         marker_0a788caa92c9951f75969114e19d19a1.bindPopup(popup_4c19baa105f5382f8a12f35965f41ffd)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #color from blue to red on same code

# %%
fg=folium.FeatureGroup(name="data")
fg.add_child(folium.Marker(location=[27.58493923900005,84.43457351300003],popup='chitwan',icon = folium.Icon(color='red')))
map.add_child(fg)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8541a768897f0dc86308b3a5a8257178 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8541a768897f0dc86308b3a5a8257178&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8541a768897f0dc86308b3a5a8257178 = L.map(
#                 &quot;map_8541a768897f0dc86308b3a5a8257178&quot;,
#                 {
#                     center: [27.58493923900005, 84.43457351300003],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86ff8c040aa203b180180d79b217f38c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8541a768897f0dc86308b3a5a8257178);
#
#
#             var marker_0a788caa92c9951f75969114e19d19a1 = L.marker(
#                 [27.58493923900005, 84.43457351300003],
#                 {}
#             ).addTo(map_8541a768897f0dc86308b3a5a8257178);
#
#
#             var icon_93aebc0ace772bf9a4310e237d3ba09f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0a788caa92c9951f75969114e19d19a1.setIcon(icon_93aebc0ace772bf9a4310e237d3ba09f);
#
#
#         var popup_4c19baa105f5382f8a12f35965f41ffd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eae00700af11ebb461cf5d9b8efdee38 = $(`&lt;div id=&quot;html_eae00700af11ebb461cf5d9b8efdee38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;chitwan&lt;/div&gt;`)[0];
#                 popup_4c19baa105f5382f8a12f35965f41ffd.setContent(html_eae00700af11ebb461cf5d9b8efdee38);
#
#
#
#         marker_0a788caa92c9951f75969114e19d19a1.bindPopup(popup_4c19baa105f5382f8a12f35965f41ffd)
#         ;
#
#
#
#
#             var feature_group_3d63553fbc9079fbc0a71edaa1e602ee = L.featureGroup(
#                 {}
#             ).addTo(map_8541a768897f0dc86308b3a5a8257178);
#
#
#             var marker_c6a12350c5c738c77e67d5d1a8fab56e = L.marker(
#                 [27.58493923900005, 84.43457351300003],
#                 {}
#             ).addTo(feature_group_3d63553fbc9079fbc0a71edaa1e602ee);
#
#
#             var icon_507574855573e7702a4c00c8dcbfc08c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c6a12350c5c738c77e67d5d1a8fab56e.setIcon(icon_507574855573e7702a4c00c8dcbfc08c);
#
#
#         var popup_c556d6b5341863aabb304e7f43360f84 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_141c0f273df957a7b9b59c6013e05159 = $(`&lt;div id=&quot;html_141c0f273df957a7b9b59c6013e05159&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;chitwan&lt;/div&gt;`)[0];
#                 popup_c556d6b5341863aabb304e7f43360f84.setContent(html_141c0f273df957a7b9b59c6013e05159);
#
#
#
#         marker_c6a12350c5c738c77e67d5d1a8fab56e.bindPopup(popup_c556d6b5341863aabb304e7f43360f84)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #Install and import pandas

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #Link Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Import CSV file

# %%
data = pd.read_csv('/content/drive/MyDrive/project work data/data cal/colab/Data/ground_data /groundstations.csv')

# %%
data.head(5) #check proper number of title Index by head method
# Out:
#    Station Index                  Name       District   Latitude  Longitude  \
# 0       100601.0              Gumthang  Sindhupalchok  27.865346  85.860160
# 1          937.0            Charchhare        Chitwan  27.423200  84.303700
# 2          938.0  Riewkhola (Bankatta)        Chitwan  27.503344  84.278768
# 3          936.0          Govindabasti        Chitwan  27.417400  84.450900
# 4          903.0               Jhuwani        Chitwan  27.590900  84.522300
#
#    Elevation
# 0     1890.0
# 1      171.0
# 2      105.0
# 3      227.0
# 4      177.0

# %%
data #again check of csv file all details completely.
# Out:
#     Station Index                    Name         District   Latitude  \
# 0        100601.0                Gumthang    Sindhupalchok  27.865346
# 1           937.0              Charchhare          Chitwan  27.423200
# 2           938.0    Riewkhola (Bankatta)          Chitwan  27.503344
# 3           936.0            Govindabasti          Chitwan  27.417400
# 4           903.0                 Jhuwani          Chitwan  27.590900
# 5           904.0         Chisapani Gadhi        Makwanpur  27.559733
# 6           915.0             Markhu Gaun       Makawanpur  27.619000
# 7           928.0              Shaktikhor          Chitwan  27.721136
# 8           931.0                Meghauli          Chitwan  27.580483
# 9           932.0          Madi Kalyanpur          Chitwan  27.433333
# 10          934.0                  Gajuri         Dhading   27.803136
# 11          935.0               Majhimtar          Dhading  27.805504
# 12         1006.0                Gumthang    Sindhupalchok  27.865353
# 13         1008.0                Nawalpur    Sindhupalchok  27.813061
# 14         1017.0               Duwachaur    Sindhupalchok  27.857188
# 15         1018.0               Baunepati    Sindhupalchok  27.792489
# 16         1023.0              Dolal Ghat            Kavre  27.638822
# 17         1035.0                  Sankhu        Kathmandu  27.744367
# 18          919.0         Makwanpur Gadhi        Makwanpur  27.416200
# 19          930.0                Shilinge        Makwanpur  27.635100
# 20         1025.0         Dhap (Thangpal)    Sindhupalchok  27.912452
# 21            NaN                    Lele              NaN  27.577778
# 22            NaN           Bahun Tiplung              NaN  27.180000
# 23         1104.0                  Melung          Dolakha  27.513304
# 24         1054.0               Thamachit           Rasuwa  28.183522
# 25         1058.0            Tarke Ghyang    Sindhupalchok  27.999318
# 26         1060.0              Chapa Gaun         Lalitpur  27.603258
# 27         1062.0               Sangachok    Sindhupalchok  27.683854
# 28         1063.0                Thokarpa    Sindhupalchok  27.687663
# 29            NaN  Sundarijal (Mulkharka)       Khthamandu  27.772619
# 30         1075.0                    Lele         Lalitpur  27.577778
# 31         1076.0                  Naikap        Kathmandu  27.700942
# 32         1077.0     Sundarijal (Alapot)       Kathamandu  27.750072
# 33            NaN       Dhap (Tarnamlang)    Sindhupaichok  27.901426
# 34         1079.0                Nagarjun       Kathamandu  27.757878
# 35         1080.0               Tikathali         Lalitpur  27.659325
# 36         1081.0            Jitpurphedhi       Kathamandu  27.784192
# 37         1082.0                Nangkhel        Bhaktapur  27.645725
# 38         1101.0                 Nagdaha          Dolakha  27.676331
# 39         1108.0           Bahun Tilpung         Sindhuli  27.166770
# 40         1117.0            Hariharpur G         sindhuli  27.333333
# 41         1049.0        Khopasi(Panauti)  Kavrepalanchowk  27.572253
# 42         1115.0               Nepalthok         Sindhuli  27.419825
#
#     Longitude  Elevation
# 0   85.860160     1890.0
# 1   84.303700      171.0
# 2   84.278768      105.0
# 3   84.450900      227.0
# 4   84.522300      177.0
# 5   85.138600     1729.0
# 6   85.149600     1535.0
# 7   84.585256      333.0
# 8   84.224222      157.0
# 9   84.383333      240.0
# 10  84.878054      430.0
# 11  84.705439      327.0
# 12  85.860148     1885.0
# 13  85.624100     1653.0
# 14  85.566385     1481.0
# 15  85.572646      774.0
# 16  85.704981      659.0
# 17  85.476900     1436.0
# 18  85.156200     1050.0
# 19  84.741500      802.0
# 20  85.633379     1284.0
# 21  85.353056        NaN
# 22  86.160000     1417.0
# 23  86.058485     1536.0
# 24  85.301839     1770.0
# 25  85.554444     2596.0
# 26  85.326564     1478.0
# 27  85.706520     1195.0
# 28  85.778612     1565.0
# 29  85.427786     1658.0
# 30  85.353056     1590.0
# 31  85.255475     1477.0
# 32  85.431189     1384.0
# 33  85.632501     1347.0
# 34  85.277158     1393.0
# 35  85.369708     1305.0
# 36  85.290494     1409.0
# 37  85.461583     1413.0
# 38  86.103994      909.0
# 39  86.192650     1129.0
# 40  85.500000      880.0
# 41  85.528553     1442.0
# 42  85.848644      690.0

# %%
a_list= data[['Station Index','District',"Latitude",'Longitude']].values.tolist() # assign above Index with proper arrangement

# %%
a_list
# Out:
# [[100601.0, 'Sindhupalchok', 27.865346, 85.86016],
#  [937.0, 'Chitwan', 27.4232, 84.3037],
#  [938.0, 'Chitwan', 27.503344, 84.278768],
#  [936.0, 'Chitwan', 27.4174, 84.4509],
#  [903.0, 'Chitwan', 27.5909, 84.5223],
#  [904.0, 'Makwanpur', 27.55973278, 85.1386],
#  [915.0, 'Makawanpur', 27.619, 85.1496],
#  [928.0, 'Chitwan', 27.72113611, 84.58525556],
#  [931.0, 'Chitwan', 27.58048333, 84.22422222],
#  [932.0, 'Chitwan', 27.433333, 84.383333],
#  [934.0, 'Dhading ', 27.803136, 84.878054],
#  [935.0, 'Dhading', 27.8055043, 84.7054395],
#  [1006.0, 'Sindhupalchok', 27.8653534, 85.8601477],
#  [1008.0, 'Sindhupalchok', 27.81306111, 85.6241],
#  [1017.0, 'Sindhupalchok', 27.857188, 85.566385],
#  [1018.0, 'Sindhupalchok', 27.79248889, 85.57264583],
#  [1023.0, 'Kavre', 27.63882194, 85.70498083],
#  [1035.0, 'Kathmandu', 27.74436667, 85.4769],
#  [919.0, 'Makwanpur', 27.4162, 85.1562],
#  [930.0, 'Makwanpur', 27.6351, 84.7415],
#  [1025.0, 'Sindhupalchok', 27.91245194, 85.633379],
#  [nan, nan, 27.577778, 85.353056],
#  [nan, nan, 27.18, 86.16],
#  [1104.0, 'Dolakha', 27.513304, 86.058485],
#  [1054.0, ' Rasuwa', 28.18352222, 85.30183889],
#  [1058.0, 'Sindhupalchok', 27.999318, 85.5544444],
#  [1060.0, 'Lalitpur', 27.60325833, 85.32656389],
#  [1062.0, 'Sindhupalchok', 27.6838541, 85.7065205],
#  [1063.0, 'Sindhupalchok', 27.68766278, 85.77861194],
#  [nan, 'Khthamandu', 27.77261944, 85.42778611],
#  [1075.0, 'Lalitpur', 27.57777778, 85.35305556],
#  [1076.0, 'Kathmandu', 27.70094167, 85.255475],
#  [1077.0, 'Kathamandu', 27.75007222, 85.43118889],
#  [nan, 'Sindhupaichok', 27.901426, 85.63250083],
#  [1079.0, 'Kathamandu', 27.75787778, 85.27715833],
#  [1080.0, 'Lalitpur', 27.659325, 85.36970833],
#  [1081.0, 'Kathamandu', 27.78419167, 85.29049444],
#  [1082.0, 'Bhaktapur', 27.645725, 85.46158333],
#  [1101.0, 'Dolakha', 27.67633111, 86.10399389],
#  [1108.0, 'Sindhuli', 27.16677, 86.19265],
#  [1117.0, 'sindhuli', 27.33333333, 85.5],
#  [1049.0, 'Kavrepalanchowk', 27.57225278, 85.52855278],
#  [1115.0, 'Sindhuli', 27.419825, 85.84864444]]

# %%
import folium
data_map=folium.Map(location =[26.68666667,87.87888889])
fg=folium.FeatureGroup(name="data")



for i in a_list:

  fg.add_child(folium.Marker(location=[i[2],i[3]],popup=i[1],icon=folium.Icon(color="pink")))
data_map.add_child(fg)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f36f9242fcf74ef53ee037e8f5792376 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f36f9242fcf74ef53ee037e8f5792376&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f36f9242fcf74ef53ee037e8f5792376 = L.map(
#                 &quot;map_f36f9242fcf74ef53ee037e8f5792376&quot;,
#                 {
#                     center: [26.68666667, 87.87888889],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94086f82540a7ca1a1adb394519f4e3b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f36f9242fcf74ef53ee037e8f5792376);
#
#
#             var feature_group_2459373bc00b08a956a60d6dca3c996f = L.featureGroup(
#                 {}
#             ).addTo(map_f36f9242fcf74ef53ee037e8f5792376);
#
#
#             var marker_3b480b56a8a4e8c49bb848563db7f273 = L.marker(
#                 [27.865346, 85.86016],
#                 {}
#             ).addTo(feature_group_2459373bc00b08a956a60d6dca3c996f);
#
#
#             var icon_f6d6194919976a29d7072c44acf95c39 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3b480b56a8a4e8c49bb848563db7f273.setIcon(icon_f6d6194919976a29d7072c44acf95c39);
#
#
#         var popup_15c36bb1c2f2238cec050c152eee34c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29db2083dd5309eaed5de08a7f07b92c = $(`&lt;div id=&quot;html_29db2083dd5309eaed5de08a7f07b92c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sindhupalchok&lt;/div&gt;`)[0];
#                 popup_15c36bb1c2f2238cec050c152eee34c9.setContent(html_29db2083dd5309eaed5de08a7f07b92c);
#
#
#
#         marker_3b480b56a8a4e8c49bb848563db7f273.bindPopup(popup_15c36bb1c2f2238cec050c152eee34c9)
#         ;
#
#
#
#
#             var marker_7c4608c02075031ca2bdb8589f9974ab = L.marker(
#                 [27.4232, 84.3037],
#                 {}
#             ).addTo(feature_group_2459373bc00b08a956a60d6dca3c996f);
#
#
#             var icon_ed4c12b772f840a8ccba50bba1c7f42b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7c4608c02075031ca2bdb8589f9974ab.setIcon(icon_ed4c12b772f840a8ccba50bba1c7f42b);
#
#
#         var popup_327c560ba5783941ec0316ca31d13b8d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c40c1fd023ef4316ccbc4bf7c0fb4172 = $(`&lt;div id=&quot;html_c40c1fd023ef4316ccbc4bf7c0fb4172&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chitwan&lt;/div&gt;`)[0];
#                 popup_327c560ba5783941ec0316ca31d13b8d.setContent(html_c40c1fd023ef4316ccbc4bf7c0fb4172);
#
#
#
#         marker_7c4608c02075031ca2bdb8589f9974ab.bindPopup(popup_327c560ba5783941ec0316ca31d13b8d)
#         ;
#
#
#
#
#             var marker_83a466a4066a9180a9c157e0ebc024d4 = L.marker(
#                 [27.503344, 84.278768],
#                 {}
#             ).addTo(feature_group_2459373bc00b08a956a60d6dca3c996f);
#
#
#             var icon_bb0cff21702aa8dbdb74937a266cda2a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_83a466a4066a9180a9c157e0ebc024d4.setIcon(icon_bb0cff21702aa8dbdb74937a266cda2a);
#
#
#         var popup_3422c8c6583c371f5bf08c7bf0488cfd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0349ee70e01ec4c3e3bb9b37b053c95b = $(`&lt;div id=&quot;html_0349ee70e01ec4c3e3bb9b37b053c95b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chitwan&lt;/div&gt;`)[0];
#                 popup_3422c8c6583c371f5bf08c7bf0488cfd.setContent(html_0349ee70e01ec4c3e3bb9b37b053c95b);
#
#
#
#         marker_83a466a4066a9180a9c157e0ebc024d4.bindPopup(popup_3422c8c6583c371f5bf08c7bf0488cfd)
#         ;
#
#
#
#
#             var marker_d3bbfd322c9a8e977f6488359fd4a523 = L.marker(
#                 [27.4174, 84.4509],
#                 {}
#             ).addTo(feature_group_2459373bc00b08a956a60d6dca

# %%
data_map.save("bagmati.html")#you can save your data in any format like jpg,png and html
